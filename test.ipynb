# %%
from PIL import Image
img = Image.open('images/dog.jpg') #Path Relativo
# img = Image.open('C:/Users/ifoa/Desktop/Prova/dog.jpg>') #Path Assoluto, da evitare!!
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x224>
